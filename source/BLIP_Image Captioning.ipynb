# %% [markdown]
# Clone repo for BLIP - Remember to run at Colab GPU environment

# %%
# !git clone https://github.com/cobanov/image-captioning.git
# Out:
# Cloning into 'image-captioning'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 221 (delta 73), reused 188 (delta 41), pack-reused 0
# Receiving objects: 100% (221/221), 28.83 MiB | 36.67 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# %cd image-captioning/
# Out:
# /content/image-captioning/image-captioning/image-captioning

# %% [markdown]
# Create checkpoint folder and download Blip model file

# %%
# %mkdir Checkpoints

# %%
# %cd Checkpoints
# Out:
# /content/image-captioning/image-captioning/image-captioning/Checkpoints

# %%
# !wget https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# Out:
# --2024-04-05 12:39:00--  https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.195.207, 173.194.196.207, 173.194.197.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.195.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1785411505 (1.7G) [application/octet-stream]
# Saving to: ‘model_large_caption.pth’
#
# model_large_caption 100%[===================>]   1.66G   239MB/s    in 9.5s
#
# 2024-04-05 12:39:10 (178 MB/s) - ‘model_large_caption.pth’ saved [1785411505/1785411505]

# %%
# %cd ..
# Out:
# /content/image-captioning/image-captioning/image-captioning

# %%
# !pip install virtualenv

# %% [markdown]
# Create Virtual Environment

# %%
# !virtualenv myenv
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 285ms
#   creator CPython3Posix(dest=/content/image-captioning/image-captioning/image-captioning/myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==24.0, setuptools==69.1.0, wheel==0.42.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/image-captioning/myenv/bin/activate

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached timm-0.4.12-py3-none-any.whl (376 kB)
# ...
#   Using cached transformers-4.17.0-py3-none-any.whl (3.8 MB)
# ...
#   Using cached fairscale-0.4.4.tar.gz (235 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
# ...
#   Using cached sacremoses-0.1.1-py3-none-any.whl (897 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %% [markdown]
# Run Inference file

# %%
# !python inference.py -i /content/image-captioning/images --batch 8 --gpu 0
# Out:
# Device: cuda:0
# Images found: 79
# Split size: 9
# checkpoint directory did not found.
# Directory is created checkpoints
#   0% 0.00/1.79G [00:00<?, ?iB/s]Downloading checkpoint...
# 100% 1.79G/1.79G [00:26<00:00, 66.8MiB/s]
# Checkpoint downloaded!
# Checkpoint loading...
# Downloading: 100% 226k/226k [00:00<00:00, 1.14MB/s]
# Downloading: 100% 48.0/48.0 [00:00<00:00, 264kB/s]
# Downloading: 100% 570/570 [00:00<00:00, 2.88MB/s]
# load checkpoint from ./checkpoints/model_large_caption.pth
#
# Model to cuda:0
# Inference started
# 0batch [00:00, ?batch/s]captions directory did not found.
# Directory is created captions
# 2024-04-05 12:42:51.243761: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
